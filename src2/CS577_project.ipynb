# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras import Model
from tensorflow.keras.utils import to_categorical
import pandas as pd
from tensorflow.keras.optimizers import RMSprop, Adam
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import load_img, img_to_array
import keras.backend as K
import pickle
from tensorflow.keras.utils import to_categorical
from keras.layers import Input
from tensorflow.keras.layers import (
    BatchNormalization, Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense,concatenate,add
)
from keras.optimizers import SGD
import glob
from PIL import Image
from tensorflow.keras.callbacks import ModelCheckpoint
from tqdm.notebook import tqdm
import seaborn as sns
from keras import Sequential
import math
import keras
from keras.preprocessing import image

# %% [markdown]
# ## Loading Data

# %%
BASE_DIR = 'UTKFace/'

image_paths = []
age_labels = []
gender_labels = []

for filename in tqdm(os.listdir(BASE_DIR)):
    image_path = os.path.join(BASE_DIR, filename)
    temp = filename.split('_')
    age = int(temp[0])
    gender = int(temp[1])
    image_paths.append(image_path)
    age_labels.append(age)
    gender_labels.append(gender)
    
# convert to dataframe
df = pd.DataFrame()
df['image'], df['age'], df['gender'] = image_paths, age_labels, gender_labels
gender_dict = {0:'Male', 1:'Female'}

def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image)
        img = img.resize((32, 32), Image.ANTIALIAS)
        img = np.array(img)
        features.append(img)
        
    features = np.array(features)
    
    return features

X = extract_features(df['image'])
X = X/255.0

y_gender = np.array(df['gender'])
y_age = np.array(df['age'])
x_train = X[:14000]
y_gender_train = y_gender[:14000]
x_va = X[13000:]
y_gender_va = y_gender[13000:]
# Out:
#   0%|          | 0/23708 [00:00<?, ?it/s]
#   0%|          | 0/23708 [00:00<?, ?it/s]
# /var/folders/_t/v4x0rpks373cv_vh41d28_800000gn/T/ipykernel_1641/3057271880.py:25: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = img.resize((32, 32), Image.ANTIALIAS)

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ## Build Gender Network

# %%
def plot_loss_his(history):
    fig1 = plt.figure("Figure 1")
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    # plt.ylim([0, 100])
    plt.xlabel('Epoch')
    plt.ylabel('loss')
    plt.title("")
    plt.legend()
    plt.grid(True)
    
def plot_acc_his(history):
    fig1 = plt.figure("Figure 2")
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    # plt.ylim([0, 100])
    plt.xlabel('Epoch')
    plt.ylabel('acc')
    plt.title("")
    plt.legend()
    plt.grid(True)

# %%
# n = 64,128,256,512
def residual_module(inputs, n):
   # 1x1 conv with n filters
    identity_layer = Conv2D(n, (1,1), activation='relu')(inputs)
    
    conv_1 = Conv2D(n, kernel_size=(1, 1), activation='relu',padding='same') (inputs)
    conv_1 = layers.BatchNormalization()(conv_1)
    conv_2 = Conv2D(n, kernel_size=(3, 3), activation='relu',padding='same') (conv_1)
    conv_2 = layers.BatchNormalization()(conv_2)
    conv_3 = Conv2D(n, kernel_size=(1, 1), activation='relu',padding='same') (conv_2)
    conv_3 = layers.BatchNormalization()(conv_3)
  
    out = add([conv_2, identity_layer])
    out = Activation('relu')(out)
    return out

input_shape = (32, 32, 3)
inputs = Input((input_shape))

#pre-conv layer
pre_conv = Conv2D(64,(7,7),activation='relu',padding='same')(inputs)
pre_layer = MaxPooling2D(pool_size=(3, 3))(pre_conv)


# Level 1 of residual, 32 conv filters
L1 = residual_module(pre_layer, 32)

# # Level 2 of residual, 64 conv filters
L2 = residual_module(L1, 64)

# # Level 3 of residual, 128 conv filters
L3 = residual_module(L2, 128)

# # Level 4 of residual, 256 conv filters
L4 = residual_module(L3, 256)


# Outer level of residual block
L0_identity = Conv2D(256, (1,1), padding='same', activation='relu', kernel_initializer='he_normal')(pre_layer)
bottleneck = add([L4, L0_identity])
bottleneck = Activation('relu')(bottleneck)
bottleneck = layers.BatchNormalization()(bottleneck)


# max pooling
bottleneck = layers.MaxPooling2D(pool_size=(4, 4))(bottleneck)
flatten = Flatten() (bottleneck)

# fully connected layers
dense_1 = Dense(256, activation='relu') (flatten)


dropout_1 = Dropout(0.3) (dense_1)
dropout_1 = Dropout(0.5) (dropout_1)

output_1 = Dense(1, activation='sigmoid', name='gender_out') (dropout_1)


gender_model = Model(inputs=inputs, outputs=output_1)

gender_model.compile(optimizer="adam", 
              loss={
                  'gender_out': 'binary_crossentropy'},
              metrics={       
                  'gender_out': 'accuracy'})
model.summary()
# Out:
# Model: "model_46"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_49 (InputLayer)          [(None, 32, 32, 3)]  0           []
#
#  conv2d_389 (Conv2D)            (None, 32, 32, 64)   9472        ['input_49[0][0]']
#
#  max_pooling2d_95 (MaxPooling2D  (None, 10, 10, 64)  0           ['conv2d_389[0][0]']
#  )
#
#  conv2d_391 (Conv2D)            (None, 10, 10, 32)   2080        ['max_pooling2d_95[0][0]']
#
#  batch_normalization_265 (Batch  (None, 10, 10, 32)  128         ['conv2d_391[0][0]']
#  Normalization)
#
#  conv2d_392 (Conv2D)            (None, 10, 10, 32)   9248        ['batch_normalization_265[0][0]']
#
#  batch_normalization_266 (Batch  (None, 10, 10, 32)  128         ['conv2d_392[0][0]']
#  Normalization)
#
#  conv2d_390 (Conv2D)            (None, 10, 10, 32)   2080        ['max_pooling2d_95[0][0]']
#
#  add_95 (Add)                   (None, 10, 10, 32)   0           ['batch_normalization_266[0][0]',
#                                                                   'conv2d_390[0][0]']
#
#  activation_95 (Activation)     (None, 10, 10, 32)   0           ['add_95[0][0]']
#
#  conv2d_395 (Conv2D)            (None, 10, 10, 64)   2112        ['activation_95[0][0]']
#
#  batch_normalization_268 (Batch  (None, 10, 10, 64)  256         ['conv2d_395[0][0]']
#  Normalization)
#
#  conv2d_396 (Conv2D)            (None, 10, 10, 64)   36928       ['batch_normalization_268[0][0]']
#
#  batch_normalization_269 (Batch  (None, 10, 10, 64)  256         ['conv2d_396[0][0]']
#  Normalization)
#
#  conv2d_394 (Conv2D)            (None, 10, 10, 64)   2112        ['activation_95[0][0]']
#
#  add_96 (Add)                   (None, 10, 10, 64)   0           ['batch_normalization_269[0][0]',
#                                                                   'conv2d_394[0][0]']
#
#  activation_96 (Activation)     (None, 10, 10, 64)   0           ['add_96[0][0]']
#
#  conv2d_399 (Conv2D)            (None, 10, 10, 128)  8320        ['activation_96[0][0]']
#
#  batch_normalization_271 (Batch  (None, 10, 10, 128)  512        ['conv2d_399[0][0]']
#  Normalization)
#
#  conv2d_400 (Conv2D)            (None, 10, 10, 128)  147584      ['batch_normalization_271[0][0]']
#
#  batch_normalization_272 (Batch  (None, 10, 10, 128)  512        ['conv2d_400[0][0]']
#  Normalization)
#
#  conv2d_398 (Conv2D)            (None, 10, 10, 128)  8320        ['activation_96[0][0]']
#
#  add_97 (Add)                   (None, 10, 10, 128)  0           ['batch_normalization_272[0][0]',
#                                                                   'conv2d_398[0][0]']
#
#  activation_97 (Activation)     (None, 10, 10, 128)  0           ['add_97[0][0]']
#
#  conv2d_403 (Conv2D)            (None, 10, 10, 256)  33024       ['activation_97[0][0]']
#
#  batch_normalization_274 (Batch  (None, 10, 10, 256)  1024       ['conv2d_403[0][0]']
#  Normalization)
#
#  conv2d_404 (Conv2D)            (None, 10, 10, 256)  590080      ['batch_normalization_274[0][0]']
#
#  batch_normalization_275 (Batch  (None, 10, 10, 256)  1024       ['conv2d_404[0][0]']
#  Normalization)
#
#  conv2d_402 (Conv2D)            (None, 10, 10, 256)  33024       ['activation_97[0][0]']
#
#  add_98 (Add)                   (None, 10, 10, 256)  0           ['batch_normalization_275[0][0]',
#                                                                   'conv2d_402[0][0]']
#
#  activation_98 (Activation)     (None, 10, 10, 256)  0           ['add_98[0][0]']
#
#  conv2d_406 (Conv2D)            (None, 10, 10, 256)  16640       ['max_pooling2d_95[0][0]']
#
#  add_99 (Add)                   (None, 10, 10, 256)  0           ['activation_98[0][0]',
#                                                                   'conv2d_406[0][0]']
#  activation_99 (Activation)     (None, 10, 10, 256)  0           ['add_99[0][0]']
#
#  batch_normalization_277 (Batch  (None, 10, 10, 256)  1024       ['activation_99[0][0]']
#  Normalization)
#
#  max_pooling2d_96 (MaxPooling2D  (None, 2, 2, 256)   0           ['batch_normalization_277[0][0]']
#  )
#
#  flatten_45 (Flatten)           (None, 1024)         0           ['max_pooling2d_96[0][0]']
#
#  dense_62 (Dense)               (None, 256)          262400      ['flatten_45[0][0]']
#
#  dropout_63 (Dropout)           (None, 256)          0           ['dense_62[0][0]']
#
#  dropout_64 (Dropout)           (None, 256)          0           ['dropout_63[0][0]']
#
#  gender_out (Dense)             (None, 1)            257         ['dropout_64[0][0]']
#
# ==================================================================================================
# Total params: 1,168,545
# Trainable params: 1,166,113
# Non-trainable params: 2,432
# __________________________________________________________________________________________________

# %%
# train model
history = gender_model.fit(x=x_train, y=y_gender_train, batch_size=64, epochs=35, validation_data=[x_va,y_gender_va])
gender_model.save("gender_model")
# Out:
# Epoch 1/35
# 2022-11-05 16:02:10.341378: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 219/219 [==============================] - ETA: 0s - loss: 0.7593 - accuracy: 0.6658
# 2022-11-05 16:02:27.085306: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 219/219 [==============================] - 22s 85ms/step - loss: 0.7593 - accuracy: 0.6658 - val_loss: 0.6680 - val_accuracy: 0.6236
# Epoch 2/35
# 219/219 [==============================] - 15s 68ms/step - loss: 0.4555 - accuracy: 0.7813 - val_loss: 0.5352 - val_accuracy: 0.6908
# Epoch 3/35
# 219/219 [==============================] - 16s 73ms/step - loss: 0.3545 - accuracy: 0.8391 - val_loss: 0.3668 - val_accuracy: 0.8450
# Epoch 4/35
# 219/219 [==============================] - 16s 73ms/step - loss: 0.3193 - accuracy: 0.8568 - val_loss: 0.3606 - val_accuracy: 0.8546
# Epoch 5/35
# 219/219 [==============================] - 15s 67ms/step - loss: 0.2896 - accuracy: 0.8711 - val_loss: 0.3250 - val_accuracy: 0.8574
# Epoch 6/35
# 219/219 [==============================] - 14s 63ms/step - loss: 0.2670 - accuracy: 0.8821 - val_loss: 0.3637 - val_accuracy: 0.8325
# Epoch 7/35
# 219/219 [==============================] - 14s 64ms/step - loss: 0.2625 - accuracy: 0.8849 - val_loss: 0.3566 - val_accuracy: 0.8436
# Epoch 8/35
# 219/219 [==============================] - 14s 62ms/step - loss: 0.2349 - accuracy: 0.8966 - val_loss: 0.4668 - val_accuracy: 0.7463
# Epoch 9/35
# 219/219 [==============================] - 14s 62ms/step - loss: 0.2179 - accuracy: 0.9071 - val_loss: 0.2979 - val_accuracy: 0.8724
# Epoch 10/35
# 219/219 [==============================] - 13s 62ms/step - loss: 0.2066 - accuracy: 0.9126 - val_loss: 0.3290 - val_accuracy: 0.8560
# Epoch 11/35
# 219/219 [==============================] - 14s 66ms/step - loss: 0.2037 - accuracy: 0.9130 - val_loss: 0.3111 - val_accuracy: 0.8593
# Epoch 12/35
# 219/219 [==============================] - 14s 63ms/step - loss: 0.1845 - accuracy: 0.9201 - val_loss: 0.3385 - val_accuracy: 0.8479
# Epoch 13/35
# 219/219 [==============================] - 14s 62ms/step - loss: 0.1693 - accuracy: 0.9302 - val_loss: 0.2655 - val_accuracy: 0.8820
# Epoch 14/35
# 219/219 [==============================] - 14s 62ms/step - loss: 0.1573 - accuracy: 0.9343 - val_loss: 0.3972 - val_accuracy: 0.8097
# Epoch 15/35
# 219/219 [==============================] - 14s 62ms/step - loss: 0.1557 - accuracy: 0.9343 - val_loss: 0.3741 - val_accuracy: 0.8323
# Epoch 16/35
# 219/219 [==============================] - 14s 62ms/step - loss: 0.1367 - accuracy: 0.9406 - val_loss: 0.2994 - val_accuracy: 0.8726
# Epoch 17/35
# 219/219 [==============================] - 14s 63ms/step - loss: 0.1277 - accuracy: 0.9476 - val_loss: 0.3099 - val_accuracy: 0.8662
# Epoch 18/35
# 219/219 [==============================] - 14s 64ms/step - loss: 0.1146 - accuracy: 0.9539 - val_loss: 0.3097 - val_accuracy: 0.8651
# Epoch 19/35
# 219/219 [==============================] - 14s 64ms/step - loss: 0.1066 - accuracy: 0.9559 - val_loss: 0.3162 - val_accuracy: 0.8586
# Epoch 20/35
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0943 - accuracy: 0.9621 - val_loss: 0.3797 - val_accuracy: 0.8447
# Epoch 21/35
# 219/219 [==============================] - 14s 64ms/step - loss: 0.1047 - accuracy: 0.9594 - val_loss: 0.3952 - val_accuracy: 0.8108
# Epoch 22/35
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0895 - accuracy: 0.9639 - val_loss: 0.3205 - val_accuracy: 0.8647
# Epoch 23/35
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0813 - accuracy: 0.9690 - val_loss: 0.3701 - val_accuracy: 0.8599
# Epoch 24/35
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0737 - accuracy: 0.9709 - val_loss: 0.5213 - val_accuracy: 0.7963
# Epoch 25/35
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0742 - accuracy: 0.9711 - val_loss: 0.3380 - val_accuracy: 0.8818
# Epoch 26/35
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0677 - accuracy: 0.9737 - val_loss: 0.3644 - val_accuracy: 0.8686
# Epoch 27/35
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0590 - accuracy: 0.9779 - val_loss: 0.3540 - val_accuracy: 0.8848
# Epoch 28/35
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0557 - accuracy: 0.9805 - val_loss: 0.3657 - val_accuracy: 0.8706
# Epoch 29/35
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0579 - accuracy: 0.9782 - val_loss: 0.3319 - val_accuracy: 0.8708
# Epoch 30/35
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0597 - accuracy: 0.9783 - val_loss: 0.3581 - val_accuracy: 0.8610
# Epoch 31/35
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0467 - accuracy: 0.9826 - val_loss: 0.3794 - val_accuracy: 0.8782
# Epoch 32/35
# 219/219 [==============================] - 14s 63ms/step - loss: 0.0460 - accuracy: 0.9832 - val_loss: 0.3801 - val_accuracy: 0.8597
# Epoch 33/35
# 219/219 [==============================] - 14s 63ms/step - loss: 0.0501 - accuracy: 0.9812 - val_loss: 0.3755 - val_accuracy: 0.8694
# Epoch 34/35
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0364 - accuracy: 0.9853 - val_loss: 0.4389 - val_accuracy: 0.8710
# Epoch 35/35
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0487 - accuracy: 0.9823 - val_loss: 0.3866 - val_accuracy: 0.8738
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 14). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: gender_model/assets
# INFO:tensorflow:Assets written to: gender_model/assets

# %%
plot_acc_his(history)
plot_loss_his(history)

# %% [markdown]
# ## Build Age network

# %%
BASE_DIR = 'UTKFace/'

image_paths = []
age_labels = []
gender_labels = []

for filename in tqdm(os.listdir(BASE_DIR)):
    image_path = os.path.join(BASE_DIR, filename)
    temp = filename.split('_')
    age = int(temp[0])
    gender = int(temp[1])
    image_paths.append(image_path)
    age_labels.append(age)
    gender_labels.append(gender)
    
# convert to dataframe
df = pd.DataFrame()
df['image'], df['age'], df['gender'] = image_paths, age_labels, gender_labels
gender_dict = {0:'Male', 1:'Female'}
df.sample(frac=1)
# Out:
#   0%|          | 0/23708 [00:00<?, ?it/s]
#                                                image  age  gender
# 19292  UTKFace/30_1_0_20170117151337477.jpg.chip.jpg   30       1
# 11281  UTKFace/28_0_0_20170114030950715.jpg.chip.jpg   28       0
# 5676   UTKFace/54_0_0_20170120223421389.jpg.chip.jpg   54       0
# 6506   UTKFace/24_1_2_20170116170646374.jpg.chip.jpg   24       1
# 1505   UTKFace/26_1_3_20170117174259928.jpg.chip.jpg   26       1
# ...                                              ...  ...     ...
# 6033   UTKFace/51_0_0_20170111181750495.jpg.chip.jpg   51       0
# 4648   UTKFace/36_0_0_20170117162925765.jpg.chip.jpg   36       0
# 9216   UTKFace/40_0_0_20170117135352413.jpg.chip.jpg   40       0
# 4047   UTKFace/22_1_3_20170117143734089.jpg.chip.jpg   22       1
# 5900   UTKFace/51_0_0_20170105172830957.jpg.chip.jpg   51       0
#
# [23708 rows x 3 columns]

# %%
display(Image.open(df['image'][19]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200>

# %%
sns.set_theme()
sns.displot(df['age'],kde=True, bins=30)

# %%
age24_28 = []

for i in range(len(df)):
    if df['age'].iloc[i] >=24 and df['age'].iloc[i] <=28:
        age24_28.append(df.iloc[i])
age24_28 = pd.DataFrame(age24_28)
age24_28 = age24_28.sample(frac=0.3)

df1 = df[df['age'] <24]
df2 = df[df['age'] >28]
df = pd.concat([df1,df2, age24_28], ignore_index = True)

# %%
sns.set_theme()
sns.distplot(df['age'],kde=True, bins=30)
# Out:
# /var/folders/_t/v4x0rpks373cv_vh41d28_800000gn/T/ipykernel_1641/1167467153.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'],kde=True, bins=30)
# <AxesSubplot: xlabel='age', ylabel='Density'>

# %%
df = df[df['age']<=60]

# %%
sns.set_theme()
sns.distplot(df['age'],kde=True, bins=30)
# Out:
# /var/folders/_t/v4x0rpks373cv_vh41d28_800000gn/T/ipykernel_1641/1167467153.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'],kde=True, bins=30)
# <AxesSubplot: xlabel='age', ylabel='Density'>

# %%
age_under4 = []

for i in range(len(df)):
    if df['age'].iloc[i] <=4:
        age_under4.append(df.iloc[i])
age_under4 = pd.DataFrame(age_under4)
age_under4 = age_under4.sample(frac=0.5)

df1 = df[df['age'] >4]
df = pd.concat([df1, age_under4], ignore_index = True)

# %%
sns.set_theme()
sns.distplot(df['age'],kde=True, bins=30)
# Out:
# /var/folders/_t/v4x0rpks373cv_vh41d28_800000gn/T/ipykernel_1641/1167467153.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'],kde=True, bins=30)
# <AxesSubplot: xlabel='age', ylabel='Density'>

# %%
# train, validate data split
X = extract_features(df['image'])
X = X/255.0
y_age = np.array(df['age'])

age_off = 5
num_group = 60//age_off
age_group = []

for i in range(len(y_age)):
    group_num = int(math.ceil(y_age[i]/age_off))
    age_group.append(group_num)
    
y_age = np.array(age_group)
y_age = to_categorical(y_age)
# Out:
#   0%|          | 0/16502 [00:00<?, ?it/s]
# /var/folders/_t/v4x0rpks373cv_vh41d28_800000gn/T/ipykernel_1641/3057271880.py:25: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = img.resize((32, 32), Image.ANTIALIAS)

# %%
min(age_group)
# Out:
# 1

# %%
x_train = X[:14000]
y_age_train = y_age[:14000]
x_va = X[11000:14500]
y_age_va = y_age[11000:14500]

# %%
X.shape
# Out:
# (16502, 32, 32, 3)

# %%
# split data based on gender, then do age group prediction

# %%
inputs = Input((32,32,3))
conv1 = keras.layers.Conv2D(filters = 16 , kernel_size = (3,3) , padding = 'same' , activation = 'relu') (inputs)
conv1 = layers.BatchNormalization()(conv1)
maxpool1 = keras.layers.MaxPool2D((2,2)) (conv1)

conv2 = keras.layers.Conv2D(filters = 32 , kernel_size = (3,3) , padding = 'same' , activation = 'relu') (maxpool1)
conv2 = layers.BatchNormalization()(conv2)
maxpool2 = keras.layers.MaxPool2D((2,2)) (conv2)


conv3 = keras.layers.Conv2D(filters = 64 , kernel_size = (3,3) , padding = 'same' , activation = 'relu') (maxpool2)
conv3 = layers.BatchNormalization()(conv3)
maxpool3 = keras.layers.MaxPool2D((2,2)) (conv3)

# Flatten

flatten = keras.layers.Flatten()(maxpool3)

# Dense Layer

dense = keras.layers.Dense(128 , activation = 'relu') (flatten)

dense = layers.BatchNormalization()(dense)
drop = keras.layers.Dropout(0.4) (dense)

# Output 

output = keras.layers.Dense(num_group+1, activation = 'softmax' , name = 'gender_output') (drop)




age_model =  keras.models.Model(inputs=[inputs], outputs = [output])

age_model.compile(
    optimizer=  'adam',
    loss= 'categorical_crossentropy',
    metrics = 'accuracy'
)

# %%
history = age_model.fit(x= x_train , y = y_age_train, batch_size=64, epochs=50, validation_data=(x_va, y_age_va))
age_model.save("age_model")
# Out:
# Epoch 1/50
# 2022-11-05 19:32:24.227283: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 219/219 [==============================] - ETA: 0s - loss: 2.6891 - accuracy: 0.1583
# 2022-11-05 19:32:30.897942: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 219/219 [==============================] - 8s 32ms/step - loss: 2.6891 - accuracy: 0.1583 - val_loss: 2.6260 - val_accuracy: 0.1363
# Epoch 2/50
# 219/219 [==============================] - 5s 24ms/step - loss: 2.1693 - accuracy: 0.2309 - val_loss: 2.0777 - val_accuracy: 0.2131
# Epoch 3/50
# 219/219 [==============================] - 5s 23ms/step - loss: 1.9728 - accuracy: 0.2768 - val_loss: 1.9045 - val_accuracy: 0.2546
# Epoch 4/50
# 219/219 [==============================] - 5s 23ms/step - loss: 1.8526 - accuracy: 0.3093 - val_loss: 1.8218 - val_accuracy: 0.2669
# Epoch 5/50
# 219/219 [==============================] - 5s 23ms/step - loss: 1.7583 - accuracy: 0.3366 - val_loss: 1.7184 - val_accuracy: 0.3297
# Epoch 6/50
# 219/219 [==============================] - 5s 23ms/step - loss: 1.6901 - accuracy: 0.3634 - val_loss: 1.8940 - val_accuracy: 0.2591
# Epoch 7/50
# 219/219 [==============================] - 5s 23ms/step - loss: 1.6250 - accuracy: 0.3847 - val_loss: 1.7191 - val_accuracy: 0.3377
# Epoch 8/50
# 219/219 [==============================] - 5s 23ms/step - loss: 1.5654 - accuracy: 0.4063 - val_loss: 1.5365 - val_accuracy: 0.4189
# Epoch 9/50
# 219/219 [==============================] - 5s 23ms/step - loss: 1.4964 - accuracy: 0.4358 - val_loss: 2.0743 - val_accuracy: 0.2543
# Epoch 10/50
# 219/219 [==============================] - 5s 23ms/step - loss: 1.4380 - accuracy: 0.4576 - val_loss: 1.6254 - val_accuracy: 0.3771
# Epoch 11/50
# 219/219 [==============================] - 5s 23ms/step - loss: 1.3920 - accuracy: 0.4737 - val_loss: 1.4145 - val_accuracy: 0.4837
# Epoch 12/50
# 219/219 [==============================] - 5s 23ms/step - loss: 1.3145 - accuracy: 0.5071 - val_loss: 1.4600 - val_accuracy: 0.4597
# Epoch 13/50
# 219/219 [==============================] - 5s 23ms/step - loss: 1.2543 - accuracy: 0.5297 - val_loss: 1.3097 - val_accuracy: 0.5277
# Epoch 14/50
# 219/219 [==============================] - 5s 23ms/step - loss: 1.1959 - accuracy: 0.5557 - val_loss: 1.3563 - val_accuracy: 0.5126
# Epoch 15/50
# 219/219 [==============================] - 5s 23ms/step - loss: 1.1372 - accuracy: 0.5749 - val_loss: 1.2882 - val_accuracy: 0.5429
# Epoch 16/50
# 219/219 [==============================] - 5s 23ms/step - loss: 1.0873 - accuracy: 0.5944 - val_loss: 1.2105 - val_accuracy: 0.5717
# Epoch 17/50
# 219/219 [==============================] - 5s 23ms/step - loss: 1.0205 - accuracy: 0.6176 - val_loss: 1.2685 - val_accuracy: 0.5729
# Epoch 18/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.9698 - accuracy: 0.6377 - val_loss: 1.2604 - val_accuracy: 0.5620
# Epoch 19/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.9319 - accuracy: 0.6569 - val_loss: 1.1485 - val_accuracy: 0.6303
# Epoch 20/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.8634 - accuracy: 0.6856 - val_loss: 1.1217 - val_accuracy: 0.6311
# Epoch 21/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.8303 - accuracy: 0.6887 - val_loss: 1.0290 - val_accuracy: 0.6694
# Epoch 22/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.7889 - accuracy: 0.7114 - val_loss: 1.0215 - val_accuracy: 0.6694
# Epoch 23/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.7431 - accuracy: 0.7289 - val_loss: 1.0111 - val_accuracy: 0.6934
# Epoch 24/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.7128 - accuracy: 0.7400 - val_loss: 0.9848 - val_accuracy: 0.6891
# Epoch 25/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.6879 - accuracy: 0.7473 - val_loss: 1.0876 - val_accuracy: 0.6583
# Epoch 26/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.6329 - accuracy: 0.7706 - val_loss: 0.8915 - val_accuracy: 0.7269
# Epoch 27/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.6047 - accuracy: 0.7773 - val_loss: 1.0339 - val_accuracy: 0.6857
# Epoch 28/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.5988 - accuracy: 0.7838 - val_loss: 0.8014 - val_accuracy: 0.7803
# Epoch 29/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.5383 - accuracy: 0.8073 - val_loss: 0.9128 - val_accuracy: 0.7380
# Epoch 30/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.5200 - accuracy: 0.8088 - val_loss: 0.8262 - val_accuracy: 0.7637
# Epoch 31/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.5182 - accuracy: 0.8129 - val_loss: 0.8782 - val_accuracy: 0.7700
# Epoch 32/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.4799 - accuracy: 0.8296 - val_loss: 0.8900 - val_accuracy: 0.7540
# Epoch 33/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.4919 - accuracy: 0.8231 - val_loss: 0.7780 - val_accuracy: 0.8040
# Epoch 34/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.4597 - accuracy: 0.8331 - val_loss: 0.8901 - val_accuracy: 0.7763
# Epoch 35/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.4255 - accuracy: 0.8460 - val_loss: 0.8751 - val_accuracy: 0.7940
# Epoch 36/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.4222 - accuracy: 0.8449 - val_loss: 0.8592 - val_accuracy: 0.7726
# Epoch 37/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.4054 - accuracy: 0.8537 - val_loss: 0.7066 - val_accuracy: 0.8406
# Epoch 38/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.3991 - accuracy: 0.8573 - val_loss: 0.6869 - val_accuracy: 0.8369
# Epoch 39/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.4029 - accuracy: 0.8560 - val_loss: 0.8287 - val_accuracy: 0.8189
# Epoch 40/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.3990 - accuracy: 0.8548 - val_loss: 0.7771 - val_accuracy: 0.8300
# Epoch 41/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.3681 - accuracy: 0.8676 - val_loss: 0.7221 - val_accuracy: 0.8326
# Epoch 42/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.3678 - accuracy: 0.8701 - val_loss: 0.8598 - val_accuracy: 0.8151
# Epoch 43/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.3482 - accuracy: 0.8738 - val_loss: 0.8035 - val_accuracy: 0.8154
# Epoch 44/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.3739 - accuracy: 0.8660 - val_loss: 0.8239 - val_accuracy: 0.8106
# Epoch 45/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.3600 - accuracy: 0.8721 - val_loss: 0.7406 - val_accuracy: 0.8443
# Epoch 46/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.3339 - accuracy: 0.8823 - val_loss: 0.6945 - val_accuracy: 0.8563
# Epoch 47/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.3134 - accuracy: 0.8901 - val_loss: 0.7905 - val_accuracy: 0.8286
# Epoch 48/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.3421 - accuracy: 0.8794 - val_loss: 0.8792 - val_accuracy: 0.8123
# Epoch 49/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.3255 - accuracy: 0.8881 - val_loss: 1.0790 - val_accuracy: 0.7829
# Epoch 50/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.3042 - accuracy: 0.8932 - val_loss: 0.6547 - val_accuracy: 0.8589
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: age_model/assets
# INFO:tensorflow:Assets written to: age_model/assets

# %%
def plot_loss_his(history):
    fig1 = plt.figure("Figure 1")
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    # plt.ylim([0, 100])
    plt.xlabel('Epoch')
    plt.ylabel('loss')
    plt.title("")
    plt.legend()
    plt.grid(True)
    
def plot_acc_his(history):
    fig1 = plt.figure("Figure 2")
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    # plt.ylim([0, 100])
    plt.xlabel('Epoch')
    plt.ylabel('acc')
    plt.title("")
    plt.legend()
    plt.grid(True)

# %%
plot_acc_his(history)
plot_loss_his(history)

# %%
def pred_gender_age_group(idx):
    
    im = X[idx].reshape(1,32,32,3)
    # age group predict
    age_pred = age_model.predict(im)
    i = np.argmax(age_pred.flatten())
    low = age_off * (i-1)
    high = age_off * i
    
    # gender predict
    gender_pred = gender_model.predict(im)
    pred_gender = "male" if gender_pred.flatten()[0] <= 0.5 else "femal"
    true_gender = "male" if df["gender"][idx] ==0 else "femal"
    
    
    # print info 
    print("True gender: ", true_gender)
    print("Predict gender: ", pred_gender)
    print("True Age: ", df['age'][idx])
    print("Predict age group: %d - %d "%(low,high))
    img = Image.open(df['image'].iloc[idx])
    display(img)

# %%
pred_gender_age_group(7)
# Out:
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 14ms/step
# True gender:  male
# Predict gender:  male
# True Age:  22
# Predict age group: 20 - 25
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200>
